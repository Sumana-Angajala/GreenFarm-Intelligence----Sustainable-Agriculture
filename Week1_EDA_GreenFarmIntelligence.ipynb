# %%
# 📌 Step 1: Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 📌 Step 2: Load Dataset
df = pd.read_csv(r"C:\Users\suman\Downloads\archive (4)\Crop_recommendation.csv")  # make sure the CSV is in the same folder
print("✅ Dataset Loaded Successfully!")
print("Shape:", df.shape)

# 📌 Step 3: Preview Dataset
df.head()
# Out:
# ✅ Dataset Loaded Successfully!
# Shape: (2200, 8)
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# 📌 Step 4: Dataset Info
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# ...

# %%
# 📌 Step 5: Check Missing Values
print("Missing Values per Column:")
print(df.isnull().sum())
# Out:
# Missing Values per Column:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# 📌 Step 6: Feature Distributions
features = ['N','P','K','temperature','humidity','ph','rainfall']

for feat in features:
    plt.figure(figsize=(6,3))
    sns.histplot(df[feat], kde=True, bins=20, color="green")
    plt.title(f"Distribution of {feat}")
    plt.show()

# %%
# 📌 Step 7: Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df[features].corr(), annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap of Features")
plt.show()

# %%
# 📌 Step 8: Crop Distribution
plt.figure(figsize=(10,5))
df['label'].value_counts().plot(kind="bar", color="seagreen")
plt.title("Crop Distribution")
plt.xlabel("Crop")
plt.ylabel("Count")
plt.show()
